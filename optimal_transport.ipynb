# %% [markdown]
# # Optimal Transport
#
# see:
#     http://alexhwilliams.info/itsneuronalblog/2020/10/09/optimal-transport/
#
# for the blog post on ot I have found.

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

X = np.random.uniform(0,1 ,100) 
X = np.exp(X) / np.sum(np.exp(X))
print(np.sum(X))
plt.hist(X, bins=30, density=True, alpha=0.5, color='red')
# Out:
# 1.0000000000000002
# (array([150.01397139, 150.01397139, 150.01397139, 150.01397139,
#         240.02235422, 150.01397139,  90.00838283, 150.01397139,
#         150.01397139,  90.00838283,  60.00558856, 120.01117711,
#         180.01676567, 150.01397139,  90.00838283,  60.00558856,
#          60.00558856,   0.        ,   0.        , 150.01397139,
#          60.00558856,  90.00838283, 120.01117711,  30.00279428,
#          30.00279428, 120.01117711,  30.00279428,  60.00558856,
#          90.00838283,  30.00279428]),
#  array([0.00603639, 0.00636969, 0.00670299, 0.00703629, 0.0073696 ,
#         0.0077029 , 0.0080362 , 0.0083695 , 0.0087028 , 0.00903611,
#         0.00936941, 0.00970271, 0.01003601, 0.01036932, 0.01070262,
#         0.01103592, 0.01136922, 0.01170253, 0.01203583, 0.01236913,
#         0.01270243, 0.01303573, 0.01336904, 0.01370234, 0.01403564,
#         0.01436894, 0.01470225, 0.01503555, 0.01536885, 0.01570215,
#         0.01603545]),
#  <BarContainer object of 30 artists>)
